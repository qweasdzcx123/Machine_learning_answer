# %% [markdown]
# ###  **10.1** 编程实现k近邻分类器，在西瓜数据集上比较其分类便捷与决策树分类边界之异同

# %%
from knn10_1 import main
'''
①加载数据集　m*n　　　m个数据　n个特征值　
②生成m*m矩阵　计算每个数据之间的欧式距离
③对于每一个样本，选取欧式距离值最小的k个值，取样本标记的平均值作为其预测标记
④画图
'''
main()
